# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %%
import pymysql

# %%
con=pymysql.connect(host="mysql-gaurav-hirulkargaurav348-6e84.h.aivencloud.com",port=26168,user="avnadmin",password="AVNS_liKX8-67OO77oJC7wH4",database="project1db")
print("Database is successfully connected")
# Out:
# Database is successfully connected

# %%
curs=con.cursor()

# %%
cutid=int(input('Enter customer id :'))
name=input('Enter name : ')
mobileno=input('Enter your mobile number : ')
carnm=input('Enter your car name : ')
city=input('Enter your city name : ')
curs.execute(f"insert into customers values({cutid},'{name}','{mobileno}','{carnm}','{city}')")
con.commit()
print("Data has been inserted successfully ")
# Out:
# Enter customer id :116
# Enter name : om
# Enter your mobile number : 895862321348
# Enter your car name : swift
# Enter your city name : wardha
# Data has been inserted successfully

# %%
cutid=int(input('Enter customer id :'))
name=input('Enter name : ')
mobileno=input('Enter your mobile number : ')
carnm=input('Enter your car name : ')
city=input('Enter your city name : ')
curs.execute(f"insert into customers values({cutid},'{name}','{mobileno}','{carnm}','{city}')")
con.commit()
print("Data has been inserted successfully ")
# Out:
# Enter customer id :115
# Enter name : soham
# Enter your mobile number : 7894587894
# Enter your car name : honda
# Enter your city name : nagpur
# Data has been inserted successfully

# %% [markdown]
# **DELETE FROM CUSTOMERS**

# %%
cid=int(input('Enter the customers id : '))
curs.execute(f"delete from customers where cutid={cid}")
con.commit()
print("data has been deleted ")
# Out:
# Enter the customers id : 110
# data has been deleted
