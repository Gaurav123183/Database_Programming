# %%
pip install pymongo

# %%
from pymongo import MongoClient

# %%
try:
  client=MongoClient("mongodb+srv://Gaurav:mongodb@gaurav.lp7ams1.mongodb.net/?retryWrites=true&w=majority&authSource=admin&appName=Gaurav")
  print("Successfully connected to MongoDB Atlas!")
except:
  print("Could not connect to MongoDB Atlas")
# Out:
# Successfully connected to MongoDB Atlas!

# %%
db=client["customers"]

# %%
coll=db["details"]

# %%
for doc in coll.find():
  print(doc)
# Out:
# {'_id': ObjectId('68181b83e6e757465eb5f89a'), 'name': 'Gaurav', 'rollno': 25, 'mobile': 963258741}
# {'_id': ObjectId('68182219aedb809bbe72e2dd'), 'rollno': 56, 'name': 'mithu', 'clgnm': 'sipna', 'no': '87945613'}

# %%
aclgnm=input("Enter college name : ")
rollno=int(input("Enter roll number : "))
name=input("Enter the name : ")
# Out:
# Enter college name : pote
# Enter roll number : 50
# Enter the name : aditya

# %%
dict={}
dict['name']=name
dict['rollno']=rollno
dict['college_name']=clgnm
print(dict)
# Out:
# {'name': 'aditya', 'rollno': 50, 'college_name': 'pote'}

# %%
coll.insert_one(dict)
print("done")
# Out:
# done
