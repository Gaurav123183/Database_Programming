# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.5 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
try:
  client=MongoClient("mongodb+srv://Gaurav:mongodb@gaurav.lp7ams1.mongodb.net/?retryWrites=true&w=majority&appName=Gaurav")
  print("Connected to MongoDB")
except:
  print("Could not connect to MongoDB")
# Out:
# Connected to MongoDB

# %%
db=client["numpy"]

# %%
coll=db["cricket"]

# %%
for lst in coll.find():
  print(lst)
# Out:
# {'_id': ObjectId('683d6bac4b22683508b5f899'), 'name': 'Gaurav', 'age': 45}
# {'_id': ObjectId('683d6d5d4b22683508b5f89a'), 'name': 'virat', 'century': 34, 'team': 'RCB'}
# {'_id': ObjectId('683d6ebb4b22683508b5f89d'), 'name': 'mithilesh', 'age': 54}
# {'_id': ObjectId('683d6ebb4b22683508b5f89e'), 'name': 'Aditya', 'age': 99, 'work': 'MECH ENGG'}

# %%
for lst in coll.find({"name":"virat"}):
  print(lst)
# Out:
# {'_id': ObjectId('683d6d5d4b22683508b5f89a'), 'name': 'virat', 'century': 34, 'team': 'RCB'}

# %%
nm=input("Enter name:")
tp=int(input("Enter trophy : "))
cen=int(input("Enter Century : "))
coll.insert_one({"name":nm,"trophy":tp,"century":cen})
print("Data inserted Successfully")
for lst in coll.find():
  print(lst)
# Out:
# Enter name:hardik
# Enter trophy : 5
# Enter Century : 67
# Data inserted Successfully
# {'_id': ObjectId('683d6bac4b22683508b5f899'), 'name': 'Gaurav', 'age': 45}
# {'_id': ObjectId('683d6d5d4b22683508b5f89a'), 'name': 'virat', 'century': 34, 'team': 'RCB'}
# {'_id': ObjectId('683d6ebb4b22683508b5f89d'), 'name': 'mithilesh', 'age': 54}
# {'_id': ObjectId('683d6ebb4b22683508b5f89e'), 'name': 'Aditya', 'age': 99, 'work': 'MECH ENGG'}
# {'_id': ObjectId('683d751d6c12ec1342c4a696'), 'name': 'hardik', 'trophy': 5, 'century': 67}

# %%
()
