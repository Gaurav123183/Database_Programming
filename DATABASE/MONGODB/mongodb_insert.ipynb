# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 13.1 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
try:
  client=MongoClient("mongodb+srv://Gaurav:mongodb@gaurav.lp7ams1.mongodb.net/?retryWrites=true&w=majority&appName=Gaurav")
  print("Successfully connected")
except:
  print("Not connected")
# Out:
# Successfully connected

# %%
db=client["customers"]
coll=db["details"]

# %%
nm=input("Enter the name : ")
rollnm=int(input("Enter the roll number : "))
clg=input("Enter the college name : ")
course=input("Enter the course : ")
mobile=int(input("Enter the mobile number : "))
# Out:
# Enter the name : msdhoni
# Enter the roll number : 75
# Enter the college name : ram meghe
# Enter the course : Ai
# Enter the mobile number : 58697412

# %%
dict={}
dict["name"]=nm
dict["rollno"]=rollnm
dict["college"]=clg
dict["course"]=course
dict["mobile"]=mobile
print(dict)
# Out:
# {'name': 'msdhoni', 'rollno': 75, 'college': 'ram meghe', 'course': 'Ai', 'mobile': 58697412}

# %%
coll.insert_one(dict)
print(dict)
# Out:
# {'name': 'msdhoni', 'rollno': 75, 'college': 'ram meghe', 'course': 'Ai', 'mobile': 58697412, '_id': ObjectId('68196c8dd626bb0fa523f62f')}
